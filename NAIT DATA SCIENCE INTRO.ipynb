# %% [markdown]
#  CREATION OF THE DATA
#  <!-- using the markdown cell -->

# %%
# intro to jupyter notebook
    # MARKDOWN CELL 
    # CODE CELL
   # ROW CELL
# Markdown cell
# code cell

# %%
STEPS FOR DATA MANIPULATION WITH PANDAS
# Importing Pandas and Data
 # Inspecting Data
 # Selecting Data
# . Filtering Data
# Handling Missing Data

# %%
# creating a dictionary
 # A dictionary # a data structure that stores data in key-value pairs: 
# team =key
# count=value

data= { 
    'Team':["Graphic Designers", "Data Scientist", "Web Developers"], 
    'count' : [2,3,4]
 }


print (data)
# Out:
# {'Team': ['Graphic Designers', 'Data Scientist', 'Web Developers'], 'count': [2, 3, 4]}

# %%
# converting a dictionary into a dataframe

our_data=pd.DataFrame(data)
print(our_data)
# Out:
#                 Team  count
# 0  Graphic Designers      2
# 1     Data Scientist      3
# 2     Web Developers      4

# %%
# KAGLE DATASET
# loading csv file
# df = pd.read_json('data.json')
import pandas as pd
dataset=pd.read_csv(r"C:\Users\Comp science\Desktop\data science\covid_19_clean_complete.csv")

# %%
dataset
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
dataset.describe()
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %%
dataset.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
dataset.tail(10)
# Out:
#                     Province/State         Country/Region        Lat  \
# 49058                          NaN                 Malawi -13.254300
# 49059  Falkland Islands (Malvinas)         United Kingdom -51.796300
# 49060    Saint Pierre and Miquelon                 France  46.885200
# 49061                          NaN            South Sudan   6.877000
# 49062                          NaN         Western Sahara  24.215500
# 49063                          NaN  Sao Tome and Principe   0.186400
# 49064                          NaN                  Yemen  15.552727
# 49065                          NaN                Comoros -11.645500
# 49066                          NaN             Tajikistan  38.861000
# 49067                          NaN                Lesotho -29.610000
#
#             Long        Date  Confirmed  Deaths  Recovered  Active  \
# 49058  34.301500  2020-07-27       3664      99       1645    1920
# 49059 -59.523600  2020-07-27         13       0         13       0
# ...

# %%
dataset.info
# NAN Means not a number
# Out:
# <bound method DataFrame.info of       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
dataset.describe(include='all')  # Summary statistics for all columns
# Out:
#                       Province/State Country/Region           Lat  \
# count                          14664          49068  49068.000000
# unique                            78            187           NaN
# top     Australian Capital Territory          China           NaN
# freq                             188           6204           NaN
# mean                             NaN            NaN     21.433730
# std                              NaN            NaN     24.950320
# min                              NaN            NaN    -51.796300
# 25%                              NaN            NaN      7.873054
# 50%                              NaN            NaN     23.634500
# 75%                              NaN            NaN     41.204380
# max                              NaN            NaN     71.706900
#
#                 Long        Date     Confirmed         Deaths     Recovered  \
# count   49068.000000       49068  4.906800e+04   49068.000000  4.906800e+04
# ...

# %%
# Display the column titles (headers)
column_titles = dataset.columns
column_titles
dataset = dataset.dropna(subset=['Country/Region', 'Deaths'])
dataset
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...
